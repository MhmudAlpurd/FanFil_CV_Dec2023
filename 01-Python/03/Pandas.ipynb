# %%
import pandas as pd

# %%
# !ls
# Out:
# Numpy.ipynb  Pandas.ipynb  titanic.csv

# %%
df = pd.read_csv('titanic.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df_age = df.Age
df_age
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
df_age_2 = df['Age']

# %%
type(df_age_2)
# Out:
# pandas.core.series.Series

# %%
df_name = df['Name'][0]
df_name
# Out:
# 'Braund, Mr. Owen Harris'

# %%
df_age_2.isnull().sum()
# Out:
# 177

# %%
#under 15
under_15 = df[df['Age'] < 15]
under_15
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 7              8         0       3           Palsson, Master. Gosta Leonard
# 9             10         1       2      Nasser, Mrs. Nicholas (Adele Achem)
# 10            11         1       3          Sandstrom, Miss. Marguerite Rut
# 14            15         0       3     Vestrom, Miss. Hulda Amanda Adolfina
# 16            17         0       3                     Rice, Master. Eugene
# ..           ...       ...     ...                                      ...
# 827          828         1       2                    Mallet, Master. Andre
# 831          832         1       2          Richards, Master. George Sibley
# 850          851         0       3  Andersson, Master. Sigvard Harald Elias
# 852          853         0       3                  Boulos, Miss. Nourelain
# 869          870         1       3          Johnson, Master. Harold Theodor
#
# ...

# %%
df.sort_values(by='Age')
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 803          804         1       3           Thomas, Master. Assad Alexander
# 755          756         1       2                 Hamalainen, Master. Viljo
# 644          645         1       3                    Baclini, Miss. Eugenie
# 469          470         1       3             Baclini, Miss. Helene Barbara
# 78            79         1       2             Caldwell, Master. Alden Gates
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
df.groupby('Pclass').mean().Age
# Out:
# Pclass
# 1    38.233441
# 2    29.877630
# 3    25.140620
# Name: Age, dtype: float64

# %%
df_slice = df.iloc[3:8, 2:5]
df_slice
# Out:
#    Pclass                                          Name     Sex
# 3       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4       3                      Allen, Mr. William Henry    male
# 5       3                              Moran, Mr. James    male
# 6       1                       McCarthy, Mr. Timothy J    male
# 7       3                Palsson, Master. Gosta Leonard    male

# %%
df_idx = df.set_index('Name')
df_idx
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
# ...                                                         ...       ...
# Montvila, Rev. Juozas                                       887         0
# Graham, Miss. Margaret Edith                                888         1
# Johnston, Miss. Catherine Helen "Carrie"                    889         0
# Behr, Mr. Karl Howell                                       890         1
# Dooley, Mr. Patrick                                         891         0
#
# ...

# %%
df_idx.loc[['Montvila, Rev. Juozas', 'Dooley, Mr. Patrick' ]]
# Out:
#                        PassengerId  Survived  Pclass   Sex   Age  SibSp  \
# Name
# Montvila, Rev. Juozas          887         0       2  male  27.0      0
# Dooley, Mr. Patrick            891         0       3  male  32.0      0
#
#                        Parch  Ticket   Fare Cabin Embarked
# Name
# Montvila, Rev. Juozas      0  211536  13.00   NaN        S
# Dooley, Mr. Patrick        0  370376   7.75   NaN        Q

# %%
df_idx.loc['Montvila, Rev. Juozas': 'Dooley, Mr. Patrick']
# Out:
#                                           PassengerId  Survived  Pclass  \
# Name
# Montvila, Rev. Juozas                             887         0       2
# Graham, Miss. Margaret Edith                      888         1       1
# Johnston, Miss. Catherine Helen "Carrie"          889         0       3
# Behr, Mr. Karl Howell                             890         1       1
# Dooley, Mr. Patrick                               891         0       3
#
#                                              Sex   Age  SibSp  Parch  \
# Name
# Montvila, Rev. Juozas                       male  27.0      0      0
# Graham, Miss. Margaret Edith              female  19.0      0      0
# Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1      2
# Behr, Mr. Karl Howell                       male  26.0      0      0
# Dooley, Mr. Patrick                         male  32.0      0      0
#
#                                               Ticket   Fare Cabin Embarked
# Name
# ...

# %%
df['Pclass'].unique()
# Out:
# array([3, 1, 2])

# %%
df.Age.value_counts()
# Out:
# 24.00    30
# 22.00    27
# 18.00    26
# 19.00    25
# 28.00    25
#          ..
# 36.50     1
# 55.50     1
# 0.92      1
# 23.50     1
# 74.00     1
# Name: Age, Length: 88, dtype: int64

# %%
# !ls
# Out:
# Numpy.ipynb  Pandas.ipynb  titanic.csv

# %%
df_created = {'last_name': ['M.Reyhani','Z.Amini', 'A.Rezaei'] ,
             'age': [18, 20, 5], 
             'region':['Tehran', 'Kerman', 'Esfahan']}
df_created
# Out:
# {'last_name': ['M.Reyhani', 'Z.Amini', 'A.Rezaei'],
#  'age': [18, 20, 5],
#  'region': ['Tehran', 'Kerman', 'Esfahan']}

# %%
df_second = pd.DataFrame(df_created)
df_second
# Out:
#    last_name  age   region
# 0  M.Reyhani   18   Tehran
# 1    Z.Amini   20   Kerman
# 2   A.Rezaei    5  Esfahan

# %%
df_second.to_csv('CV_Staffs.csv')

# %%
# !ls
# Out:
# CV_Staffs.csv  Numpy.ipynb  Pandas.ipynb  titanic.csv

# %%
df_third = pd.read_csv('CV_Staffs.csv')
df_third
# Out:
#    Unnamed: 0  last_name  age   region
# 0           0  M.Reyhani   18   Tehran
# 1           1    Z.Amini   20   Kerman
# 2           2   A.Rezaei    5  Esfahan

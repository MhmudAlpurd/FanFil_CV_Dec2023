# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
#reading image in OPENCV
img_channels = cv2.imread(r'images/colors.png')

# %%
img_channels.shape
# Out:
# (316, 314, 3)

# %%
#cv2.imshow('image for teaching the channels', img_channels)
#cv2.waitKey(0)

# %%
#R=red, G=green, B=blue
blue_channel = img_channels[:, :, 0]
#cv2.imshow('alaki', red_channel)
#cv2.waitKey(0)
#cv2.imwrite('first_ch.jpg', blue_channel)

#OPENCV = BGR

# %%
green_channel = img_channels[:, :, 1]
#cv2.imshow('second_channel', green_channel)
#cv2.waitKey(0)

# %%
green_channel
# Out:
# array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8)

# %%
red_channel = img_channels[:, :, 2]
#cv2.imwrite('third_ch.jpg', red_channel)

# %%
c_img = cv2.imread(r'images/c_img.jpg')
#cv2.imshow('c_img', c_img)
#cv2.waitKey(0)

# %%
red_ch_c_img = c_img[:, :, 2]
#cv2.imshow('c_img', red_ch_c_img)
#cv2.waitKey(0)
#cv2.imwrite('third_ch_c_img.jpg', red_ch_c_img)

# %%
color_img = cv2.imread(r'images/colors.png')
color_to_gray = cv2.cvtColor(color_img, cv2.COLOR_BGR2GRAY)

#cv2.imshow('color2gray', color_to_gray)
#cv2.waitKey(0)

# %%
color_img.shape
# Out:
# (316, 314, 3)

# %%
color_to_gray.shape
# Out:
# (316, 314)

# %%
color_to_gray_from_first = cv2.imread('images/c_img.jpg', 0)

#cv2.imshow('color2grayfromfirst', color_to_gray_from_first)
#cv2.waitKey(0)

# %%
color_from_first = cv2.imread(r'images/c_img.jpg', 1)
img_without_any_any_changes = cv2.imread('images/c_img.jpg', -1)

# %%
b_img_for_test = cv2.imread(r'images/b_img.png')
b_img_for_test.shape
# Out:
# (204, 247, 3)

# %%
#Reading using cv2, showing using matplotlib

c_img_for_matplotlib = cv2.imread(r'images/c_img.jpg') #BGR
plt.imshow(c_img_for_matplotlib) #RGB
plt.title('Image for plt')
plt.axis('off')
# Out:
# (-0.5, 479.5, 319.5, -0.5)

# %%
c_img_for_plt_using_plt = plt.imread(r'images/c_img.jpg') #RGB
plt.imshow(c_img_for_plt_using_plt) #RGB
plt.title('Image for plt')
plt.axis('off')
# Out:
# (-0.5, 479.5, 319.5, -0.5)

# %%
c_img_for_matplotlib = cv2.imread(r'images/c_img.jpg') #BGR
bgr_to_rgb = cv2.cvtColor(c_img_for_matplotlib, cv2.COLOR_BGR2RGB) #RGB
plt.imshow(bgr_to_rgb) #RGB
plt.title('Image for plt')
plt.axis('off')
# Out:
# (-0.5, 479.5, 319.5, -0.5)

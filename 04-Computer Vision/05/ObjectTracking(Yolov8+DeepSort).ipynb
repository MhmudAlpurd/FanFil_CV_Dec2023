# %%
# !pip install torch torchvision
# !pip install opencv-python
# !pip install yolov8
# !pip install deep-sort-realtime

# %%
import torch
import cv2
#from yolov8 import YOLOv8
from deep_sort_realtime.deepsort_tracker import DeepSort

# %%
# !git clone https://github.com/python-dontrepeatyourself/Real-Time-Object-Tracking-with-DeepSORT-and-YOLOv8.git
# Out:
# fatal: destination path 'Real-Time-Object-Tracking-with-DeepSORT-and-YOLOv8' already exists and is not an empty directory.

# %%
# !pwd
# Out:
# /content

# %%
# %cd Real-Time-Object-Tracking-with-DeepSORT-and-YOLOv8/
# Out:
# /content/Real-Time-Object-Tracking-with-DeepSORT-and-YOLOv8

# %%
# !pip install ultralytics

# %%
# !ls
# Out:
# 1.mp4  helper.py	    object_detection_tracking.py  __pycache__  yolov8n.pt
# 2.mp4  object_detection.py  output.mp4			  README.md

# %%
# !python object_detection_tracking.py
# Out:
# Streaming output truncated to the last 5000 lines.
#
# 0: 384x640 2 bicycles, 5 cars, 2 traffic lights, 6.9ms
# Speed: 1.5ms preprocess, 6.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Time to process 1 frame: 29 milliseconds
#
# 0: 384x640 2 bicycles, 5 cars, 2 traffic lights, 6.8ms
# Speed: 1.5ms preprocess, 6.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Time to process 1 frame: 30 milliseconds
#
# 0: 384x640 2 bicycles, 5 cars, 2 traffic lights, 6.8ms
# Speed: 1.4ms preprocess, 6.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Time to process 1 frame: 31 milliseconds
#
# 0: 384x640 2 bicycles, 5 cars, 2 traffic lights, 6.6ms
# Speed: 1.4ms preprocess, 6.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Time to process 1 frame: 31 milliseconds
#
# 0: 384x640 1 person, 2 bicycles, 5 cars, 1 traffic light, 7.6ms
# ...
